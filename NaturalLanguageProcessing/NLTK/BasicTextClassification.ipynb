# %%
import nltk
from deep_translator import GoogleTranslator

# %%
translator = GoogleTranslator(source='auto', target='es')

# %%
nltk.download('genesis') # this library is for the genesis corpus
nltk.download('ieer') # this library is for the ieer corpus
nltk.download('indian') # this library is for the indian corpus
nltk.download('gutenberg') # this library is for the gutenberg corpus
nltk.download('inaugural') # this library is for the inaugural corpus
nltk.download('jeita') # this library is for the JeitaTagger
nltk.download('kimmo') # this library is for the KimmoTagger
nltk.download('nps_chat') # this library is for the chatbot
nltk.download('omw') # this library is for the WordNetLemmatizer
nltk.download('punkt') # this library is for the PunktSentenceTokenizer
nltk.download('sample_grammars')
nltk.download('sentence_polarity') # this library is for the movie reviews
nltk.download('spanish_grammars')
nltk.download('state_union') # this library is for the state of the union address
nltk.download('stopwords')
nltk.download('toolbox') # this library is for the ToolboxTagger
nltk.download('word2vec_sample') # this library is for the word2vec
nltk.download('wordnet')  # this library is for the WordNetLemmatizer
nltk.download('wordnet_ic') # this library is for the information content
nltk.download('words') # this library is for the words corpus
nltk.download('ycoe') # this library is for the YCOE corpus
# Out:
# [nltk_data] Downloading package genesis to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package genesis is already up-to-date!
# [nltk_data] Downloading package ieer to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package ieer is already up-to-date!
# [nltk_data] Downloading package indian to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package indian is already up-to-date!
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package inaugural to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# [nltk_data] Downloading package jeita to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package jeita is already up-to-date!
# [nltk_data] Downloading package kimmo to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package kimmo is already up-to-date!
# [nltk_data] Downloading package nps_chat to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package nps_chat is already up-to-date!
# [nltk_data] Downloading package omw to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package sample_grammars to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package sample_grammars is already up-to-date!
# [nltk_data] Downloading package sentence_polarity to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package sentence_polarity is already up-to-date!
# [nltk_data] Downloading package spanish_grammars to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package spanish_grammars is already up-to-date!
# [nltk_data] Downloading package state_union to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package toolbox to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package toolbox is already up-to-date!
# [nltk_data] Downloading package word2vec_sample to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package word2vec_sample is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet_ic to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet_ic is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package ycoe to
# [nltk_data]     C:\Users\rbblazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package ycoe is already up-to-date!
# True

# %%
from bs4 import BeautifulSoup
import requests as request

# %%
url = "https://es.wikipedia.org/wiki/Pirater%C3%ADa"

html = request.get(url).text

bs = BeautifulSoup(html, 'html5lib')

text = bs.get_text(strip=True)

text
# Out:
# 'Piratería - Wikipedia, la enciclopedia libredocument.documentElement.className="client-js";(function(){var cookie=document.cookie.match(/(?:^|; )eswikimwclientprefs=([^;]+)/);if(cookie){var featureName=cookie[1];document.documentElement.className=document.documentElement.className.replace(featureName+\'-enabled\',featureName+\'-disabled\');}}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgRequestId":"1ae4c1ca-46f4-4968-ae63-078f5f6f9d74","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Piratería","wgTitle":"Piratería","wgCurRevisionId":150279800,"wgRevisionId":150279800,"wgArticleId":21375,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[\n"Wikipedia:Páginas con enlaces mágicos de ISBN","Wikipedia:Artículos destacados","Wikipedia:Artículos con pasajes que requieren referencias","Wikipedia:Artículos con identificadores BNF","Wikipedia:Artículos con identificadores GND","Wikipedia:Artículos con identificadores LCCN","Piratería","Términos jurídicos","Derecho penal internacional"],"wgPageContentLanguage":"es","wgPageContentModel":"wikitext","wgRelevantPageName":"Piratería","wgRelevantArticleId":21375,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":true,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":100000,"wgNoticeProject":"wikipedia","wgVector2022PreviewPages":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,\n"wgULSCurrentAutonym":"español","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q45393","GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":true,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.gadget.imagenesinfobox":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","mediawiki.toc","skins.vector.legacy.js","mmv.head","mmv.bootstrap.autostart",\n"ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.a-commons-directo","ext.gadget.ReferenceTooltips","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.echo.centralauth","ext.uls.compactlinks","ext.uls.interface","ext.growthExperiments.SuggestedEditSession"];(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});});});PirateríaDe Wikipedia, la enciclopedia libreIr a la navegaciónIr a la búsquedaEste artículo trata sobre la piratería marítima. Para otros usos, véasePiratería (desambiguación).Para otros usos de «pirata» o «piratas», véasePirata (desambiguación).BanderaJolly Roger, deCalico Jack,[1]\u200b tenida como repr ...

# %% [markdown]
# ### Once we have the text, we can tokenize it into sentences and words.

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
tokens = word_tokenize(text, language='spanish')
tokens = [word.lower() for word in tokens if word.isalpha()] # remove punctuation, numbers ....

tokens
# Out:
# ['piratería',
#  'wikipedia',
#  'la',
#  'enciclopedia',
#  'function',
#  'var',
#  'if',
#  'cookie',
#  'var',
#  'wgbreakframes',
#  'false',
#  'wgseparatortransformtable',
#  'wgdigittransformtable',
#  'wgdefaultdateformat',
#  'dmy',
#  'wgmonthnames',
#  'enero',
#  'febrero',
#  'marzo',
#  'abril',
#  'mayo',
#  'junio',
#  'julio',
#  'agosto',
#  'septiembre',
#  'octubre',
#  'noviembre',
#  'diciembre',
#  'wgrequestid',
#  'wgcspnonce',
#  'false',
#  'wgcanonicalnamespace',
#  'wgcanonicalspecialpagename',
#  'false',
#  'wgnamespacenumber',
#  'wgpagename',
#  'piratería',
#  'wgtitle',
#  'piratería',
#  'wgcurrevisionid',
#  'wgrevisionid',
#  'wgarticleid',
#  'wgisarticle',
#  'true',
#  'wgisredirect',
#  'false',
#  'wgaction',
#  'view',
#  'wgusername',
#  'null',
#  'wgusergroups',
#  'wgcategories',
#  'wikipedia',
#  'páginas',
#  'con',
#  'enlaces',
#  'mágicos',
#  'de',
#  'isbn',
#  'wikipedia',
#  'artículos',
#  'destacados',
#  'wikipedia',
#  'artículos',
#  'con',
#  'pasajes',
#  'que',
#  'requieren',
#  'referencias',
#  'wikipedia',
#  'artículos',
#  'con',
#  'identificadores',
#  'bnf',
#  'wikipedia',
#  'artículos',
#  'con',
#  'identificadores',
#  'gnd',
#  'wikipedia',
#  'artículos',
#  'con',
#  'identificadores',
#  'lccn',
#  'piratería',
#  'términos',
#  'jurídicos',
#  'derecho',
#  'penal',
#  'internacional',
#  'wgpagecontentlanguage',
#  'es',
#  'wgpagecontentmodel',
#  'wikitext',
#  'wgrelevantpagename',
#  'piratería',
#  'wgrelevantarticleid',
#  'wgisprobablyeditable',
#  'true',
#  'wgrelevantpageisprobablyeditable',
#  'true',
#  'wgrestrictionedit',
#  'wgrestrictionmove',
#  'wgvisualeditor',
#  'pagelanguagecode',
#  'es',
#  'pagelanguagedir',
#  'ltr',
#  'pagevariantfallbacks',
#  'es',
#  'wgmfdisplaywikibasedescriptions',
#  'search',
#  'true',
#  'watchlist',
#  'true',
#  'tagline',
#  'true',
#  'nearby',
#  'true',
#  'wgwmeschemaeditattemptstepoversample',
#  'false',
#  'wgwmepagelength',
#  'wgnoticeproject',
#  'wikipedia',
#  'wgmediavieweronclick',
#  'true',
#  'wgmediaviewerenabledbydefault',
#  'true',
#  'wgpopupsflags',
#  'wgulscurrentautonym',
#  'español',
#  'wgeditsubmitbuttonlabelpublish',
#  'true',
#  'wgcentralauthmobiledomain',
#  'false',
#  'wgulsposition',
#  'interlanguage',
#  'wgulsiscompactlinksenabled',
#  'true',
#  'wgulsislanguageselectorempty',
#  'false',
#  'wgwikibaseitemid',
#  'gehomepagesuggestededitsenabletopics',
#  'true',
#  'wggetopicsmatchmodeenabled',
#  'true',
#  'wggestructuredtaskrejectionreasontextinputenabled',
#  'false',
#  'wggelevelingupenabledforuser',
#  'false',
#  'ready',
#  'ready',
#  'ready',
#  'ready',
#  'ready',
#  'user',
#  'ready',
#  'loading',
#  'ready',
#  'ready',
#  'ready',
#  'ready',
#  'ready',
#  'ready',
#  'site',
#  'function',
#  'function',
#  'jquery',
#  'require',
#  'module',
#  'patroltoken',
#  'watchtoken',
#  'csrftoken',
#  'pirateríade',
#  'wikipedia',
#  'la',
#  'enciclopedia',
#  'libreir',
#  'a',
#  'la',
#  'navegaciónir',
#  'a',
#  'la',
#  'búsquedaeste',
#  'artículo',
#  'trata',
#  'sobre',
#  'la',
#  'piratería',
#  'marítima',
#  'para',
#  'otros',
#  'usos',
#  'véasepiratería',
#  'desambiguación',
#  'otros',
#  'usos',
#  'de',
#  'pirata',
#  'o',
#  'piratas',
#  'véasepirata',
#  'desambiguación',
#  'roger',
#  'decalico',
#  'jack',
#  'tenida',
#  'como',
#  'representación',
#  'clásica',
#  'y',
#  'simbólica',
#  'de',
#  'la',
#  'una',
#  'práctica',
#  'desaqueoorganizado',
#  'obandolerismomarítimo',
#  'por',
#  'la',
#  'cual',
#  'se',
#  'ataca',
#  'a',
#  'unaembarcacióncon',
#  'el',
#  'propósito',
#  'de',
#  'robar',
#  'su',
#  'carga',
#  'exigir',
#  'rescate',
#  'por',
#  'los',
#  'pasajeros',
#  'o',
#  'venderlos',
#  'comoesclavos',
#  'y',
#  'en',
#  'ocasiones',
#  'apoderarse',
#  'de',
#  'la',
#  'nave',
#  'misma',
#  'su',
#  'definición',
#  'según',
#  'elderecho',
#  'internacionalpuede',
#  'encontrarse',
#  'en',
#  'el',
#  'artículo',
#  'de',
#  'laconvención',
#  'de',
#  'las',
#  'naciones',
#  'unidas',
#  'sobre',
#  'el',
#  'derecho',
#  'del',
#  'mar',
#  'tipo',
#  'especial',
#  'de',
#  'pirata',
#  'desde',
#  'el',
#  'punto',
#  'de',
#  'vista',
#  'legal',
#  'es',
#  'elcorsario',
#  'navegante',
#  'contratado',
#  'por',
#  'un',
#  'estado',
#  'mediantepatente',
#  'de',
#  'corso',
#  'para',
#  'atacar',
#  'y',
#  'saquear',
#  'las',
#  'naves',
#  'de',
#  'un',
#  'país',
#  'enemigo',
#  'disponer',
#  'del',
#  'respaldo',
#  'de',
#  'un',
#  'estado',
#  'ofrecía',
#  'la',
#  'garantía',
#  'de',
#  'ser',
#  'tratado',
#  'como',
#  'soldado',
#  'de',
#  'otro',
#  'ejército',
#  'por',
#  'el',
#  'enemigo',
#  'y',
#  'al',
#  'mismo',
#  'tiempo',
#  'acarreaba',
#  'ciertas',
#  'obligaciones',
#  'la',
#  'principal',
#  'de',
#  'las',
#  'cuales',
#  'era',
#  'entregar',
#  'parte',
#  'de',
#  'las',
#  'presas',
#  'a',
#  'las',
#  'autoridades',
#  'que',
#  'emitían',
#  'la',
#  'patente',
#  'esta',
#  'distinción',
#  'es',
#  'relativa',
#  'pues',
#  'corsarios',
#  'comofrancis',
#  'drakeo',
#  'la',
#  'flota',
#  'francesa',
#  'en',
#  'labatalla',
#  'de',
#  'la',
#  'isla',
#  'terceirafueron',
#  'considerados',
#  'piratas',
#  'por',
#  'las',
#  'autoridades',
#  'españolas',
#  'ya',
#  'que',
#  'no',
#  'existía',
#  'una',
#  'guerra',
#  'y',
#  'mar',
#  'océano',
#  'mar',
#  'del',
#  'de',
#  'la',
#  'piratería',
#  'de',
#  'las',
#  'del',
#  'de',
#  'del',
#  'de',
#  'piratería',
#  'en',
#  'piratería',
#  'en',
#  'en',
#  'los',
#  'en',
#  'la',
#  'popular',
#  'en',
#  'cine',
#  'y',
#  'y',
#  'externosetimología',
#  'y',
#  'uso',
#  'editar',
#  'el',
#  'españolamaro',
#  'pargofue',
#  'uno',
#  'de',
#  'loscorsariosmás',
#  'famosos',
#  'de',
#  'laedad',
#  'de',
#  'oro',
#  'de',
#  'la',
#  'dellatínpirāta',
#  'el',
#  'cual',
#  'es',
#  'una',
#  'adaptación',
#  'delgriegoπειρατής',
#  'peiratḗs',
#  'salteador',
#  'de',
#  'πεῖρα',
#  'peîra',
#  'intento',
#  'y',
#  'πειράω',
#  'peiraō',
#  'intentar',
#  'con',
#  'esfuerzo',
#  'usado',
#  'al',
#  'principio',
#  'en',
#  'el',
#  'sentido',
#  'de',
#  'aventurero',
#  'con',
#  'el',
#  'tiempo',
#  'tomó',
#  'el',
#  'significado',
#  'de',
#  'saqueador',
#  'término',
#  'latino',
#  'apareció',
#  'por',
#  'primera',
#  'vez',
#  'en',
#  'textos',
#  'de',
#  'cicerón',
#  'y',
#  'se',
#  'hizo',
#  'común',
#  'durante',
#  'los',
#  'últimos',
#  'años',
#  'de',
#  'la',
#  'república',
#  'romana',
#  'momento',
#  'de',
#  'auge',
#  'de',
#  'flotas',
#  'piratas',
#  'en',
#  'el',
#  'términosfilibusteroybucanero',
#  'más',
#  'específicos',
#  'están',
#  'relacionados',
#  'con',
#  'la',
#  'piratería',
#  'en',
#  'elmar',
#  'caribedurante',
#  'los',
#  'laconvención',
#  'de',
#  'las',
#  'naciones',
#  'unidas',
#  'sobre',
#  'el',
#  'derecho',
#  'del',
#  'mardio',
#  'una',
#  'definición',
#  'de',
#  'pirata',
#  'según',
#  'la',
#  'cual',
#  'se',
#  'trata',
#  'de',
#  'un',
#  'delincuente',
#  'común',
#  'que',
#  'opera',
#  'en',
#  'alta',
#  'mar',
#  'desde',
#  'una',
#  'embarcación',
#  'término',
#  'pirata',
#  'por',
#  'extensión',
#  'se',
#  'aplicó',
#  'a',
#  'otros',
#  'contextos',
#  'en',
#  'la',
#  'década',
#  'de',
#  'se',
#  'utilizó',
#  'para',
#  'designar',
#  'alsecuestro',
#  'de',
#  'aeronavesa',
#  'cambio',
#  'de',
#  'un',
#  'rescate',
#  'o',
#  'de',
#  'transporte',
#  'a',
#  'un',
#  'determinado',
#  'país',
#  'si',
#  'bien',
#  'en',
#  'estos',
#  'casos',
#  'el',
#  'objetivo',
#  'era',
#  'de',
#  'tipo',
#  'político',
#  'antes',
#  'que',
#  'lucrativo',
#  'también',
#  'se',
#  'usa',
#  'para',
#  'designar',
#  'a',
#  'quien',
#  'roba',
#  'en',
#  'una',
#  'carretera',
#  'en',
#  'especial',
#  'a',
#  'vehículos',
#  'de',
#  'transporte',
#  'de',
#  'mercaderías',
#  'en',
#  'cuyo',
#  'caso',
#  'se',
#  'lo',
#  'denomina',
#  'pirata',
#  'del',
#  'asfalto',
#  'mediados',
#  'del',
#  'sigloxx',
#  'se',
#  'denominóradio',
#  'pirataa',
#  'la',
#  'transmisión',
#  'ilegal',
#  'deradio',
#  'en',
#  'el',
#  'ámbito',
#  'de',
#  'la',
#  'informática',
#  'pirataalude',
#  'a',
#  'un',
#  'programa',
#  'que',
#  'se',
#  'introduce',
#  'ilegalmente',
#  'en',
#  'un',
#  'sistema',
#  'ajeno',
#  'con',
#  'frecuencia',
#  'para',
#  'robar',
#  'información',
#  'o',
#  'copiarla',
#  'y',
#  'distribuirla',
#  'como',
#  'sustantivo',
#  'adjetivado',
#  'pirata',
#  'designa',
#  'también',
#  'a',
#  'un',
#  'producto',
#  'o',
#  'una',
#  'marca',
#  'que',
#  'copian',
#  'ilegalmente',
#  'o',
#  'imitan',
#  'de',
#  'manera',
#  'deliberada',
#  'a',
#  'otros',
#  'navío',
#  'venganza',
#  'de',
#  'la',
#  'reina',
#  'ana',
#  'queen',
#  'anne',
#  'revenge',
#  'del',
#  'famoso',
#  'barbanegra',
#  'seudónimo',
#  'del',
#  'capitán',
#  'edward',
#  'editar',
#  'edad',
#  'antigua',
#  'editar',
#  'artículo',
#  'principal',
#  'piratería',
#  'en',
#  'el',
#  'mediterráneo',
#  'antiguolas',
#  'zonas',
#  'de',
#  'mayor',
#  'actividad',
#  'de',
#  'los',
#  'piratas',
#  'coincidían',
#  'con',
#  'las',
#  'de',
#  'mayor',
#  'tráfico',
#  'de',
#  'mercancías',
#  'y',
#  'de',
#  'personas',
#  'las',
#  'primeras',
#  'referencias',
#  'históricas',
#  'sobre',
#  'la',
#  'piratería',
#  'datan',
#  'del',
#  'siglova',
#  'en',
#  'la',
#  'llamadacosta',
#  'de',
#  'los',
#  'piratas',
#  'en',
#  'elgolfo',
#  'pérsico',
#  'su',
#  'actividad',
#  'se',
#  'mantuvo',
#  'durante',
#  'toda',
#  'laantigüedad',
#  'otras',
#  'zonas',
#  'afectadas',
#  'fueron',
#  'elmar',
#  'mediterráneoy',
#  'elmar',
#  'de',
#  'la',
#  'china',
#  'editar',
#  'los',
#  'egipcios',
#  'consideraban',
#  'piratas',
#  'a',
#  'lospueblos',
#  'del',
#  'marporque',
#  'su',
#  'principal',
#  'expedición',
#  'invasiva',
#  'se',
#  'dio',
#  'por',
#  'vía',
#  'marítima',
#  'y',
#  'con',
#  'la',
#  'finalidad',
#  'de',
#  'efectuar',
#  'saqueos',
#  'sin',
#  'embargo',
#  'muchos',
#  'otros',
#  'autores',
#  'no',
#  'comparten',
#  'esta',
#  'clasificación',
#  'porque',
#  'los',
#  'pueblos',
#  'del',
#  'mar',
#  'solo',
#  'fueron',
#  'marineros',
#  'en',
#  'el',
#  'último',
#  'momento',
#  'de',
#  'su',
#  'historia',
#  'editar',
#  'odiseo',
#  'atado',
#  'al',
#  'mástil',
#  'de',
#  'su',
#  'barco',
#  'tratando',
#  'de',
#  'vencer',
#  'la',
#  'atracción',
#  'de',
#  'las',
#  'sirenas',
#  'cuadro',
#  'las',
#  'sirenas',
#  'de',
#  'léon',
#  'belly',
#  'museo',
#  'de',
#  'sandelin',
#  'saint',
#  'omer',
#  'los',
#  'datos',
#  'no',
#  'son',
#  'muy',
#  'abundantes',
#  'por',
#  'los',
#  'mitos',
#  'sabemos',
#  'que',
#  'los',
#  'griegos',
#  'clásicos',
#  'fueron',
#  'buenos',
#  'piratas',
#  'cita',
#  'requerida',
#  'uno',
#  'de',
#  'los',
#  'más',
#  'famosos',
#  'fuejasón',
#  'quien',
#  'guio',
#  'a',
#  'losargonautashastala',
#  'cólquidaen',
#  'busca',
#  'delvellocino',
#  'de',
#  'oro',
#  'lo',
#  'que',
#  'aunque',
#  'no',
#  'entre',
#  'en',
#  'la',
#  'definición',
#  'española',
#  'de',
#  'piratería',
#  'para',
#  'algunos',
#  'es',
#  'sin',
#  'ningún',
#  'género',
#  'de',
#  'dudas',
#  'un',
#  'acto',
#  'de',
#  'piratería',
#  'personas',
#  'que',
#  'vienen',
#  'por',
#  'mar',
#  'para',
#  'robar',
#  'u',
#  'odiseo',
#  'según',
#  'las',
#  'traducciones',
#  'griega',
#  'o',
#  'latina',
#  'realizó',
#  'varios',
#  'actos',
#  'de',
#  'piratería',
#  'en',
#  'su',
#  'regreso',
#  'aítaca',
#  'como',
#  'narrahomeroen',
#  'estos',
#  'dos',
#  'ejemplos',
#  'podemos',
#  'ver',
#  'una',
#  'constante',
#  'que',
#  'se',
#  'repetirá',
#  'a',
#  'lo',
#  'largo',
#  'de',
#  'los',
#  'siglos',
#  'los',
#  'piratas',
#  'son',
#  'en',
#  'muchas',
#  'ocasiones',
#  'considerados',
#  'héroes',
#  'nacionales',
#  'en',
#  'sus',
#  'países',
#  'cita',
#  'requerida',
#  'pese',
#  'a',
#  'practicar',
#  'lo',
#  'que',
#  'en',
#  'tierra',
#  'se',
#  'llamaríaroboysecuestro',
#  'especialmente',
#  'en',
#  'una',
#  'sociedad',
#  'como',
#  'la',
#  'griega',
#  'donde',
#  'el',
#  'oficio',
#  'de',
#  'las',
#  'armas',
#  'era',
#  'reconocido',
#  'y',
#  'estimado',
#  'un',
#  'motivo',
#  'que',
#  'llevaba',
#  'a',
#  'glorificar',
#  'en',
#  'lugar',
#  'de',
#  'denostar',
#  'actos',
#  'como',
#  'el',
#  'citado',
#  'de',
#  'jasón',
#  'debe',
#  'tenerse',
#  'en',
#  'cuenta',
#  'que',
#  'el',
#  'oficio',
#  'demercenario',
#  'si',
#  'bien',
#  'es',
#  'verdad',
#  'que',
#  'es',
#  'llevado',
#  'a',
#  'cabo',
#  'en',
#  'tierra',
#  'no',
#  'tenía',
#  'connotaciones',
#  'negativas',
#  'como',
#  'las',
#  'tiene',
#  'actualmente',
#  'de',
#  'los',
#  'piratas',
#  'griegos',
#  'más',
#  'famosos',
#  ...]

# %% [markdown]
# ### now we are goint to check the frequency of each word in the text

# %%
freq = nltk.FreqDist(tokens)

for key, val in freq.items():
    print(str(key) + ':' + str(val))
# Out:
# piratería:81
# wikipedia:11
# la:627
# enciclopedia:3
# function:4
# var:2
# if:1
# cookie:1
# wgbreakframes:1
# false:10
# wgseparatortransformtable:1
# wgdigittransformtable:1
# wgdefaultdateformat:1
# dmy:1
# wgmonthnames:1
# enero:4
# febrero:9
# marzo:3
# abril:2
# mayo:3
# junio:3
# julio:4
# agosto:3
# septiembre:4
# octubre:4
# noviembre:6
# diciembre:5
# wgrequestid:1
# wgcspnonce:1
# wgcanonicalnamespace:1
# wgcanonicalspecialpagename:1
# wgnamespacenumber:1
# wgpagename:1
# wgtitle:1
# wgcurrevisionid:1
# wgrevisionid:1
# wgarticleid:1
# wgisarticle:1
# true:14
# wgisredirect:1
# wgaction:1
# view:1
# wgusername:1
# null:1
# wgusergroups:1
# wgcategories:1
# páginas:2
# con:146
# enlaces:2
# mágicos:2
# de:1178
# isbn:5
# artículos:17
# destacados:3
# pasajes:2
# que:325
# requieren:2
# referencias:3
# identificadores:6
# bnf:1
# gnd:1
# lccn:1
# términos:2
# jurídicos:1
# derecho:8
# penal:3
# internacional:4
# wgpagecontentlanguage:1
# es:53
# wgpagecontentmodel:1
# wikitext:1
# wgrelevantpagename:1
# wgrelevantarticleid:1
# wgisprobablyeditable:1
# wgrelevantpageisprobablyeditable:1
# wgrestrictionedit:1
# wgrestrictionmove:1
# wgvisualeditor:1
# pagelanguagecode:1
# pagelanguagedir:1
# ltr:1
# pagevariantfallbacks:1
# wgmfdisplaywikibasedescriptions:1
# search:1
# watchlist:1
# tagline:1
# nearby:1
# wgwmeschemaeditattemptstepoversample:1
# wgwmepagelength:1
# wgnoticeproject:1
# wgmediavieweronclick:1
# wgmediaviewerenabledbydefault:1
# wgpopupsflags:1
# wgulscurrentautonym:1
# español:10
# wgeditsubmitbuttonlabelpublish:1
# wgcentralauthmobiledomain:1
# wgulsposition:1
# interlanguage:1
# wgulsiscompactlinksenabled:1
# wgulsislanguageselectorempty:1
# wgwikibaseitemid:1
# gehomepagesuggestededitsenabletopics:1
# wggetopicsmatchmodeenabled:1
# wggestructuredtaskrejectionreasontextinputenabled:1
# wggelevelingupenabledforuser:1
# ready:12
# user:1
# loading:1
# site:1
# jquery:1
# require:1
# module:1
# patroltoken:1
# watchtoken:1
# csrftoken:1
# pirateríade:1
# libreir:1
# a:347
# navegaciónir:1
# búsquedaeste:1
# artículo:6
# trata:3
# sobre:21
# marítima:7
# para:83
# otros:28
# usos:2
# véasepiratería:1
# desambiguación:2
# pirata:64
# o:56
# piratas:166
# véasepirata:1
# roger:4
# decalico:1
# jack:3
# tenida:1
# como:99
# representación:1
# clásica:2
# y:421
# simbólica:1
# una:123
# práctica:6
# desaqueoorganizado:1
# obandolerismomarítimo:1
# por:187
# cual:10
# se:168
# ataca:1
# unaembarcacióncon:1
# el:398
# enlaza:1
# aquícambios:1
# enlazadassubir:1
# archivopáginas:1
# especialesenlace:1
# permanenteinformación:1
# páginacitar:1
# páginaelemento:1
# librodescargar:1
# pdfversión:1
# imprimiren:1
# proyectoswikimedia:1
# commonswikiquoteen:1
# nynorsknorsk:1
# englishslovenščinasoomaaligaсрпски:1
# enlacesesta:1
# página:1
# editó:1
# abr:1
# texto:1
# disponible:1
# lalicencia:1
# creative:1
# commons:1
# atribución:1
# compartir:1
# aplicarse:1
# cláusulas:1
# adicionales:1
# usar:1
# sitio:1
# usted:1
# acepta:1
# nuestrostérminos:1
# usoy:1
# nuestrapolítica:1
# registrada:1
# lafundación:1
# wikimedia:5
# ánimo:1
# privacidadacerca:1
# wikipedialimitación:1
# responsabilidadversión:1
# móvilesdesarrolladoresestadísticasdeclaración:1
# cookies:1
# wghostname:1
# wgbackendresponsetime:1
# wgpageparsereport:1
# limitreport:1
# cputime:1
# walltime:1
# ppvisitednodes:1
# value:10
# limit:10
# postexpandincludesize:1
# templateargumentsize:1
# expansiondepth:1
# expensivefunctioncount:1
# entityaccesscount:1
# timingprofile:1
# plantilla:9
# listaref:1
# scribunto:1
# cachereport:1
# origin:1
# timestamp:1
# ttl:1
# transientcontent:1
# context:2
# type:8
# article:2
# name:6
# url:4
# ada:2
# sameas:2
# http:4
# mainentity:2
# author:2
# colaboradores:2
# proyectos:2
# publisher:2
# foundation:2
# inc:2
# logo:2
# imageobject:2
# datepublished:2
# datemodified:2
# image:2
# headline:2
# organizado:2
# bandolerismo:2

# %%
import seaborn as sns

sns.set()
freq.plot(30, cumulative=False)
# Out:
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ## now we are going to remove the stop words such as determinations, which are words that are not relevant for the analysis

# %%
from nltk.corpus import stopwords
stop_words_spanish = set(stopwords.words('spanish'))
stop_words_english = set(stopwords.words('english'))
stop_words = stop_words_spanish.union(stop_words_english)

clean_tokens = tokens[:]

for token in tokens:
    if token in stop_words:
        clean_tokens.remove(token)

clean_tokens
# Out:
# ['piratería',
#  'wikipedia',
#  'enciclopedia',
#  'function',
#  'var',
#  'cookie',
#  'var',
#  'wgbreakframes',
#  'false',
#  'wgseparatortransformtable',
#  'wgdigittransformtable',
#  'wgdefaultdateformat',
#  'dmy',
#  'wgmonthnames',
#  'enero',
#  'febrero',
#  'marzo',
#  'abril',
#  'mayo',
#  'junio',
#  'julio',
#  'agosto',
#  'septiembre',
#  'octubre',
#  'noviembre',
#  'diciembre',
#  'wgrequestid',
#  'wgcspnonce',
#  'false',
#  'wgcanonicalnamespace',
#  'wgcanonicalspecialpagename',
#  'false',
#  'wgnamespacenumber',
#  'wgpagename',
#  'piratería',
#  'wgtitle',
#  'piratería',
#  'wgcurrevisionid',
#  'wgrevisionid',
#  'wgarticleid',
#  'wgisarticle',
#  'true',
#  'wgisredirect',
#  'false',
#  'wgaction',
#  'view',
#  'wgusername',
#  'null',
#  'wgusergroups',
#  'wgcategories',
#  'wikipedia',
#  'páginas',
#  'enlaces',
#  'mágicos',
#  'isbn',
#  'wikipedia',
#  'artículos',
#  'destacados',
#  'wikipedia',
#  'artículos',
#  'pasajes',
#  'requieren',
#  'referencias',
#  'wikipedia',
#  'artículos',
#  'identificadores',
#  'bnf',
#  'wikipedia',
#  'artículos',
#  'identificadores',
#  'gnd',
#  'wikipedia',
#  'artículos',
#  'identificadores',
#  'lccn',
#  'piratería',
#  'términos',
#  'jurídicos',
#  'derecho',
#  'penal',
#  'internacional',
#  'wgpagecontentlanguage',
#  'wgpagecontentmodel',
#  'wikitext',
#  'wgrelevantpagename',
#  'piratería',
#  'wgrelevantarticleid',
#  'wgisprobablyeditable',
#  'true',
#  'wgrelevantpageisprobablyeditable',
#  'true',
#  'wgrestrictionedit',
#  'wgrestrictionmove',
#  'wgvisualeditor',
#  'pagelanguagecode',
#  'pagelanguagedir',
#  'ltr',
#  'pagevariantfallbacks',
#  'wgmfdisplaywikibasedescriptions',
#  'search',
#  'true',
#  'watchlist',
#  'true',
#  'tagline',
#  'true',
#  'nearby',
#  'true',
#  'wgwmeschemaeditattemptstepoversample',
#  'false',
#  'wgwmepagelength',
#  'wgnoticeproject',
#  'wikipedia',
#  'wgmediavieweronclick',
#  'true',
#  'wgmediaviewerenabledbydefault',
#  'true',
#  'wgpopupsflags',
#  'wgulscurrentautonym',
#  'español',
#  'wgeditsubmitbuttonlabelpublish',
#  'true',
#  'wgcentralauthmobiledomain',
#  'false',
#  'wgulsposition',
#  'interlanguage',
#  'wgulsiscompactlinksenabled',
#  'true',
#  'wgulsislanguageselectorempty',
#  'false',
#  'wgwikibaseitemid',
#  'gehomepagesuggestededitsenabletopics',
#  'true',
#  'wggetopicsmatchmodeenabled',
#  'true',
#  'wggestructuredtaskrejectionreasontextinputenabled',
#  'false',
#  'wggelevelingupenabledforuser',
#  'false',
#  'ready',
#  'ready',
#  'ready',
#  'ready',
#  'ready',
#  'user',
#  'ready',
#  'loading',
#  'ready',
#  'ready',
#  'ready',
#  'ready',
#  'ready',
#  'ready',
#  'site',
#  'function',
#  'function',
#  'jquery',
#  'require',
#  'module',
#  'patroltoken',
#  'watchtoken',
#  'csrftoken',
#  'pirateríade',
#  'wikipedia',
#  'enciclopedia',
#  'libreir',
#  'navegaciónir',
#  'búsquedaeste',
#  'artículo',
#  'trata',
#  'piratería',
#  'marítima',
#  'usos',
#  'véasepiratería',
#  'desambiguación',
#  'usos',
#  'pirata',
#  'piratas',
#  'véasepirata',
#  'desambiguación',
#  'roger',
#  'decalico',
#  'jack',
#  'representación',
#  'clásica',
#  'simbólica',
#  'práctica',
#  'desaqueoorganizado',
#  'obandolerismomarítimo',
#  'ataca',
#  'unaembarcacióncon',
#  'propósito',
#  'robar',
#  'carga',
#  'exigir',
#  'rescate',
#  'pasajeros',
#  'venderlos',
#  'comoesclavos',
#  'ocasiones',
#  'apoderarse',
#  'nave',
#  'misma',
#  'definición',
#  'según',
#  'elderecho',
#  'internacionalpuede',
#  'encontrarse',
#  'artículo',
#  'laconvención',
#  'naciones',
#  'unidas',
#  'derecho',
#  'mar',
#  'tipo',
#  'especial',
#  'pirata',
#  'punto',
#  'vista',
#  'legal',
#  'elcorsario',
#  'navegante',
#  'contratado',
#  'mediantepatente',
#  'corso',
#  'atacar',
#  'saquear',
#  'naves',
#  'país',
#  'enemigo',
#  'disponer',
#  'respaldo',
#  'ofrecía',
#  'garantía',
#  'ser',
#  'tratado',
#  'soldado',
#  'ejército',
#  'enemigo',
#  'mismo',
#  'tiempo',
#  'acarreaba',
#  'ciertas',
#  'obligaciones',
#  'principal',
#  'cuales',
#  'entregar',
#  'parte',
#  'presas',
#  'autoridades',
#  'emitían',
#  'patente',
#  'distinción',
#  'relativa',
#  'pues',
#  'corsarios',
#  'comofrancis',
#  'drakeo',
#  'flota',
#  'francesa',
#  'labatalla',
#  'isla',
#  'terceirafueron',
#  'considerados',
#  'piratas',
#  'autoridades',
#  'españolas',
#  'existía',
#  'guerra',
#  'mar',
#  'océano',
#  'mar',
#  'piratería',
#  'piratería',
#  'piratería',
#  'popular',
#  'cine',
#  'externosetimología',
#  'uso',
#  'editar',
#  'españolamaro',
#  'pargofue',
#  'loscorsariosmás',
#  'famosos',
#  'laedad',
#  'oro',
#  'dellatínpirāta',
#  'adaptación',
#  'delgriegoπειρατής',
#  'peiratḗs',
#  'salteador',
#  'πεῖρα',
#  'peîra',
#  'intento',
#  'πειράω',
#  'peiraō',
#  'intentar',
#  'esfuerzo',
#  'usado',
#  'principio',
#  'aventurero',
#  'tiempo',
#  'tomó',
#  'significado',
#  'saqueador',
#  'término',
#  'latino',
#  'apareció',
#  'primera',
#  'vez',
#  'textos',
#  'cicerón',
#  'hizo',
#  'común',
#  'últimos',
#  'años',
#  'república',
#  'romana',
#  'momento',
#  'auge',
#  'flotas',
#  'piratas',
#  'términosfilibusteroybucanero',
#  'específicos',
#  'relacionados',
#  'piratería',
#  'elmar',
#  'caribedurante',
#  'laconvención',
#  'naciones',
#  'unidas',
#  'derecho',
#  'mardio',
#  'definición',
#  'pirata',
#  'según',
#  'trata',
#  'delincuente',
#  'común',
#  'opera',
#  'alta',
#  'mar',
#  'embarcación',
#  'término',
#  'pirata',
#  'extensión',
#  'aplicó',
#  'contextos',
#  'década',
#  'utilizó',
#  'designar',
#  'alsecuestro',
#  'aeronavesa',
#  'cambio',
#  'rescate',
#  'transporte',
#  'determinado',
#  'país',
#  'si',
#  'bien',
#  'casos',
#  'objetivo',
#  'tipo',
#  'político',
#  'lucrativo',
#  'usa',
#  'designar',
#  'roba',
#  'carretera',
#  'especial',
#  'vehículos',
#  'transporte',
#  'mercaderías',
#  'cuyo',
#  'caso',
#  'denomina',
#  'pirata',
#  'asfalto',
#  'mediados',
#  'sigloxx',
#  'denominóradio',
#  'pirataa',
#  'transmisión',
#  'ilegal',
#  'deradio',
#  'ámbito',
#  'informática',
#  'pirataalude',
#  'programa',
#  'introduce',
#  'ilegalmente',
#  'sistema',
#  'ajeno',
#  'frecuencia',
#  'robar',
#  'información',
#  'copiarla',
#  'distribuirla',
#  'sustantivo',
#  'adjetivado',
#  'pirata',
#  'designa',
#  'producto',
#  'marca',
#  'copian',
#  'ilegalmente',
#  'imitan',
#  'manera',
#  'deliberada',
#  'navío',
#  'venganza',
#  'reina',
#  'ana',
#  'queen',
#  'anne',
#  'revenge',
#  'famoso',
#  'barbanegra',
#  'seudónimo',
#  'capitán',
#  'edward',
#  'editar',
#  'edad',
#  'antigua',
#  'editar',
#  'artículo',
#  'principal',
#  'piratería',
#  'mediterráneo',
#  'antiguolas',
#  'zonas',
#  'mayor',
#  'actividad',
#  'piratas',
#  'coincidían',
#  'mayor',
#  'tráfico',
#  'mercancías',
#  'personas',
#  'primeras',
#  'referencias',
#  'históricas',
#  'piratería',
#  'datan',
#  'siglova',
#  'llamadacosta',
#  'piratas',
#  'elgolfo',
#  'pérsico',
#  'actividad',
#  'mantuvo',
#  'toda',
#  'laantigüedad',
#  'zonas',
#  'afectadas',
#  'elmar',
#  'mediterráneoy',
#  'elmar',
#  'china',
#  'editar',
#  'egipcios',
#  'consideraban',
#  'piratas',
#  'lospueblos',
#  'marporque',
#  'principal',
#  'expedición',
#  'invasiva',
#  'dio',
#  'vía',
#  'marítima',
#  'finalidad',
#  'efectuar',
#  'saqueos',
#  'embargo',
#  'autores',
#  'comparten',
#  'clasificación',
#  'pueblos',
#  'mar',
#  'solo',
#  'marineros',
#  'último',
#  'momento',
#  'historia',
#  'editar',
#  'odiseo',
#  'atado',
#  'mástil',
#  'barco',
#  'tratando',
#  'vencer',
#  'atracción',
#  'sirenas',
#  'cuadro',
#  'sirenas',
#  'léon',
#  'belly',
#  'museo',
#  'sandelin',
#  'saint',
#  'omer',
#  'datos',
#  'abundantes',
#  'mitos',
#  'sabemos',
#  'griegos',
#  'clásicos',
#  'buenos',
#  'piratas',
#  'cita',
#  'requerida',
#  'famosos',
#  'fuejasón',
#  'guio',
#  'losargonautashastala',
#  'cólquidaen',
#  'busca',
#  'delvellocino',
#  'oro',
#  'aunque',
#  'definición',
#  'española',
#  'piratería',
#  'ningún',
#  'género',
#  'dudas',
#  'acto',
#  'piratería',
#  'personas',
#  'vienen',
#  'mar',
#  'robar',
#  'u',
#  'odiseo',
#  'según',
#  'traducciones',
#  'griega',
#  'latina',
#  'realizó',
#  'varios',
#  'actos',
#  'piratería',
#  'regreso',
#  'aítaca',
#  'narrahomeroen',
#  'dos',
#  'ejemplos',
#  'podemos',
#  'ver',
#  'constante',
#  'repetirá',
#  'largo',
#  'siglos',
#  'piratas',
#  'muchas',
#  'ocasiones',
#  'considerados',
#  'héroes',
#  'nacionales',
#  'países',
#  'cita',
#  'requerida',
#  'pese',
#  'practicar',
#  'tierra',
#  'llamaríaroboysecuestro',
#  'especialmente',
#  'sociedad',
#  'griega',
#  'oficio',
#  'armas',
#  'reconocido',
#  'estimado',
#  'motivo',
#  'llevaba',
#  'glorificar',
#  'lugar',
#  'denostar',
#  'actos',
#  'citado',
#  'jasón',
#  'debe',
#  'tenerse',
#  'cuenta',
#  'oficio',
#  'demercenario',
#  'si',
#  'bien',
#  'verdad',
#  'llevado',
#  'cabo',
#  'tierra',
#  'connotaciones',
#  'negativas',
#  'actualmente',
#  'piratas',
#  'griegos',
#  'famosos',
#  'referencias',
#  'fuepolicrates',
#  'samos',
#  'c',
#  'saqueó',
#  'todaasia',
#  'menoren',
#  'diferentes',
#  'expediciones',
#  'llegó',
#  'reunir',
#  'barcos',
#  'editar',
#  'época',
#  'final',
#  'larepública',
#  'piratas',
#  'mediterráneo',
#  'llegaron',
#  'convertirse',
#  'peligro',
#  'bases',
#  'primero',
#  'sur',
#  'deasia',
#  'menoren',
#  'montañosas',
#  'costas',
#  'deciliciay',
#  'tarde',
#  'mediterráneo',
#  'puesto',
#  'impedían',
#  'comercio',
#  'interrumpían',
#  'líneas',
#  'suministro',
#  'diferencia',
#  'siglos',
#  'posteriores',
#  'piratas',
#  'antigüedad',
#  'buscaban',
#  'joyas',
#  'metales',
#  'preciosos',
#  'personas',
#  'sociedades',
#  'aquella',
#  'época',
#  'solían',
#  'ser',
#  'mayoríaesclavistas',
#  'captura',
#  'personas',
#  'ser',
#  'vendidas',
#  'esclavos',
#  'resultaba',
#  'práctica',
#  'altamente',
#  'lucrativa',
#  'buscaban',
#  'piedras',
#  'preciosas',
#  'metales',
#  'preciosos',
#  'esencias',
#  'telas',
#  'sal',
#  'tintes',
#  'vinoy',
#  'tipos',
#  'mercancías',
#  'solían',
#  'transportarse',
#  'barcos',
#  'mercantes',
#  'caso',
#  'losfenicios',
#  'primera',
#  'flota',
#  'romana',
#  'representado',
#  'casos',
#  'conocidos',
#  'piratería',
#  'líneas',
#  'navegación',
#  'protagonizójulio',
#  'césar',
#  'llegó',
#  'ser',
#  'prisionero',
#  'lospiratas',
#  'cilicios',
#  'paralelascuenta',
#  'jefe',
#  'cilicio',
#  'estimaba',
#  'rescate',
#  'oro',
#  'joven',
#  'césar',
#  'espetó',
#  'si',
#  'conocieras',
#  'negocio',
#  'sabrías',
#  'valgo',
#  'menos',
#  'cautiverio',
#  'duró',
#  'treinta',
#  'ocho',
#  'días',
#  'cuales',
#  'rehén',
#  'amenazó',
#  'captores',
#  'crucificarlos',
#  'finalmente',
#  'rescate',
#  'pagó',
#  'futuro',
#  'cónsul',
#  'roma',
#  'liberado',
#  'césar',
#  'cumplió',
#  'amenaza',
#  'recobró',
#  'libertad',
#  'organizó',
#  'expedición',
#  'pagada',
#  'propio',
#  'dinero',
#  'apresó',
#  'captores',
#  'crucificó',
#  'piratería',
#  'perpetrada',
#  'piratas',
#  'cilicios',
#  'alcanzó',
#  'niveles',
#  'preocupantes',
#  'roma',
#  'hacia',
#  'final',
#  'república',
#  'elsenado',
#  'romanonombró',
#  'apompeyoprocónsul',
#  'mares',
#  'significaba',
#  'otorgó',
#  'mando',
#  'supremo',
#  'mare',
#  'nostrum',
#  'mar',
#  'mediterráneo',
#  'costas',
#  'adentro',
#  'concedieron',
#  'ejércitos',
#  'encontrasen',
#  'costas',
#  'mediterráneo',
#  'contando',
#  'así',
#  'efectivos',
#  'así',
#  'derecho',
#  'tomar',
#  'tesoro',
#  'cantidad',
#  'necesitase',
#  'finalmente',
#  'proveyó',
#  'flota',
#  'bien',
#  'pertrechada',
#  'diversas',
#  'operaciones',
#  'eliminó',
#  'cuarenta',
#  'días',
#  'piratas',
#  'desiciliaeitaliay',
#  'tras',
#  'asedio',
#  'toma',
#  'decoracesion',
#  'piratas',
#  'cilicia',
#  'acabando',
#  'así',
#  'cuarenta',
#  'nueve',
#  'días',
#  'piratas',
#  'zona',
#  'oriental',
#  'mediterráneo',
#  'asimismo',
#  'debe',
#  'apuntarse',
#  'dichos',
#  'piratas',
#  'solo',
#  'presentaron',
#  'resistencia',
#  'imprescindible',
#  'poder',
#  'solicitar',
#  'rendición',
#  'media',
#  'editar',
#  'artículos',
#  'principales',
#  'alta',
#  'edad',
#  'mediaybaja',
#  'edad',
#  'divisiónhistoriográficaclásica',
#  'podemos',
#  'dividir',
#  'laedad',
#  'mediaenaltaybaja',
#  'primera',
#  'piratas',
#  'protagonistas',
#  'losvikingosy',
#  'losárabes',
#  'segunda',
#  'centro',
#  'atención',
#  'desplaza',
#  'hacia',
#  'mediterráneo',
#  'oriental',
#  'creciente',
#  'expansión',
#  'mar',
#  'adriático',
#  'editar',
#  'artículo',
#  'principal',
#  'paganiapaganiafue',
#  'territorio',
#  'poblado',
#  'tribu',
#  'eslava',
#  'conocida',
#  'losnarentinos',
#  'neretljani',
#  'zona',
#  'sur',
#  'dedalmacia',
#  'actualcroacia',
#  'oeste',
#  'río',
#  'neretva',
#  'narenta',
#  'conocidos',
#  'destreza',
#  'marítima',
#  'dedicación',
#  'nombre',
#  'pagania',
#  'responde',
#  'hecho',
#  'habitantes',
#  'considerados',
#  'paganos',
#  'pueblos',
#  'residían',
#  'regiones',
#  'vecinas',
#  'debido',
#  'dichas',
#  'poblaciones',
#  'serbios',
#  'descritos',
#  'porporphyrogenituscomo',
#  'terratenientes',
#  'habitantes',
#  'región',
#  'ciudad',
#  'ras',
#  'ríos',
#  'pliva',
#  'cetina',
#  'regiones',
#  'vivían',
#  'losneretljani',
#  'zahumljani',
#  'travunjani',
#  'konavljani',
#  'consideraban',
#  'serbios',
#  'vivían',
#  'losserbiosen',
#  'estricto',
#  'llamaban',
#  'tierra',
#  'serbia',
#  'bautizada',
#  'mediados',
#  'siglox',
#  'frontera',
#  'serbios',
#  'croatas',
#  'seguía',
#  'curso',
#  'ríos',
#  'cetina',
#  'pliva',
#  'río',
#  'cetina',
#  'extendían',
#  'tierras',
#  'losneretljani',
#  'famosos',
#  'piratas',
#  'menciona',
#  'porphyrogenitus',
#  'descendientes',
#  'serbios',
#  'bautizados',
#  'habitantes',
#  'pagania',
#  'consecuencia',
#  'cristianizados',
#  'vikingos',
#  'editar',
#  'artículo',
#  'principal',
#  'vikingorutas',
#  'años',
#  'laera',
#  'pueblo',
#  'permaneció',
#  'sumido',
#  'luchas',
#  'internas',
#  'varios',
#  'siglos',
#  'realizan',
#  'primer',
#  'ataque',
#  'costa',
#  'norte',
#  'deinglaterray',
#  'dos',
#  'años',
#  'después',
#  'fecha',
#  'después',
#  'año',
#  'pueblos',
#  'norte',
#  'efectuaron',
#  'tipo',
#  'incursiones',
#  'elmar',
#  'norte',
#  'elcantábricoy',
#  'elmediterráneo',
#  'oriental',
#  'occidental',
#  'radio',
#  'alcanzaban',
#  'excursiones',
#  'aumentando',
#  'progresivamente',
#  'según',
#  'crecían',
#  'conocimientos',
#  'costa',
#  'ríos',
#  'navegables',
#  'así',
#  'acciones',
#  'podemos',
#  'primer',
#  'ataque',
#  'lasislas',
#  'primer',
#  'ataque',
#  'ataque',
#  'actualespaíses',
#  'ataque',
#  'ataque',
#  'lapenínsula',
#  'existe',
#  'postura',
#  'unánime',
#  'historiadores',
#  ...]

# %%
freq = nltk.FreqDist(clean_tokens)

sns.set()
freq.plot(30, cumulative=False)
# Out:
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ### now we are going to get the synonyms and antonyms of each word using WORDNET

# %%
from nltk.corpus import wordnet

synonyms = []
word_to_find_synonyms_en = 'pirate'
word_to_find_synonyms_es = 'pirata'

for syn in wordnet.synsets(word_to_find_synonyms_en):
    for lemma in syn.lemmas():
        if lemma.name() not in synonyms:
            synonyms.append(lemma.name())

print(synonyms)
# Out:
# ['plagiarist', 'plagiarizer', 'plagiariser', 'literary_pirate', 'pirate', 'buccaneer', 'sea_robber', 'sea_rover', 'pirate_ship', 'commandeer', 'hijack', 'highjack']

# %% [markdown]
# ### By default WordNet only returns words in English, so we are going to use the Google Translate API to translate the words to Spanish

# %%
synonyms = list(map(lambda synonym: translator.translate(synonym), synonyms))

synonyms
# Out:
# ['plagiario',
#  'plagiador',
#  'plagiador',
#  'pirata_literario',
#  'pirata',
#  'bucanero',
#  'ladrón_del_mar',
#  'sea_rover',
#  'barco pirata',
#  'requisar',
#  'secuestrar',
#  'secuestrar']

# %%
clean_tokens_syn = clean_tokens[:]

for index, syn in enumerate(synonyms):
    clean_tokens_syn = [word.replace(synonyms[index], word_to_find_synonyms_es) for word in clean_tokens_syn]

# %%
manual_synonyms = ['barcos', 'naves']

for index, syn in enumerate(manual_synonyms):
    clean_tokens_syn = [word.replace(manual_synonyms[index], 'barcos') for word in clean_tokens_syn]

# %%
freq = nltk.FreqDist(clean_tokens_syn)

sns.set()
freq.plot(30, cumulative=False) ## as we can see 'naves' doesn't exist's and 'barcos' is most frequent now
# Out:
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ### if we want to check the antonyms we can do it in the same way

# %%
antonyms = []
word_to_find_antonyms = 'good'

for syn in wordnet.synsets(word_to_find_antonyms):
    for lemma in syn.lemmas():
        if lemma.antonyms():
            print(lemma.antonyms())
            antonyms.append(lemma.antonyms()[0].name())

antonyms
# Out:
# [Lemma('evil.n.03.evil')]
# [Lemma('evil.n.03.evilness')]
# [Lemma('bad.n.01.bad')]
# [Lemma('bad.n.01.badness')]
# [Lemma('bad.a.01.bad')]
# [Lemma('evil.a.01.evil')]
# [Lemma('ill.r.01.ill')]
# ['evil', 'evilness', 'bad', 'badness', 'bad', 'evil', 'ill']

# %%
antonyms = list(map(lambda antonym: translator.translate(antonym), antonyms))

antonyms
# Out:
# ['demonio', 'maldad', 'malo', 'maldad', 'malo', 'demonio', 'enfermo']
